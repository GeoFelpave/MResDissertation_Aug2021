# %% [markdown]
# # Donwloading HadUK-Grid Data
#
# This notebook was created to download HadUK-Grid data using the data end points from the CEDA Archive.
#
# ---
#
#  - Author:
#                     Luis F Patino Velasquez - MA
#  - Date:
#                     Jun 2020
#  - Version:
#                     1.0
#  - Notes:
#                     Files downloaded are in netCDF format,
#                     This code is a based on the code developed by Centre for Environmental Data Analysis Developers
#                     https://wiki.earthdata.nasa.gov/display/EL/How+To+Access+Data+With+Python
#  - Jupyter version:
#                     jupyter core     : 4.7.1
#                     jupyter-notebook : 6.4.0
#                     qtconsole        : 5.1.1
#                     ipython          : 7.25.0
#                     ipykernel        : 6.0.3
#                     jupyter client   : 6.1.12
#                     jupyter lab      : 3.0.16
#                     nbconvert        : 6.1.0
#                     ipywidgets       : 7.6.3
#                     nbformat         : 5.1.3
#                     traitlets        : 5.0.5
#  - Python version:
#                     3.8.5
#
# ---

# %%
# Import standard libraries
import os
import sys
import datetime
import requests
from requests.packages.urllib3.exceptions import InsecureRequestWarning
from pathlib import Path
from dateutil.relativedelta import relativedelta
import calendar

# Import third-party libraries
from cryptography import x509
from cryptography.hazmat.backends import default_backend
from contrail.security.onlineca.client import OnlineCaClient

# hide warning about request
requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

CERTS_DIR = os.path.expanduser('~/.certs')
if not os.path.isdir(CERTS_DIR):
    os.makedirs(CERTS_DIR)

TRUSTROOTS_DIR = os.path.join(CERTS_DIR, 'ca-trustroots')
CREDENTIALS_FILE_PATH = os.path.join(CERTS_DIR, 'credentials.pem')

TRUSTROOTS_SERVICE = 'https://slcs.ceda.ac.uk/onlineca/trustroots/'
CERT_SERVICE = 'https://slcs.ceda.ac.uk/onlineca/certificate/'

sep = ('''------------\n------------''')


def cert_is_valid(cert_file, min_lifetime=0):
    """
    Returns boolean - True if the certificate is in date.
    Optional argument min_lifetime is the number of seconds
    which must remain.
    :param cert_file: certificate file path.
    :param min_lifetime: minimum lifetime (seconds)
    :return: boolean
    """
    try:
        with open(cert_file, 'rb') as f:
            crt_data = f.read()
    except IOError:
        return False

    try:
        cert = x509.load_pem_x509_certificate(crt_data, default_backend())
    except ValueError:
        return False

    now = datetime.datetime.now()

    return (cert.not_valid_before <= now
            and cert.not_valid_after > now + datetime.timedelta(0, min_lifetime))


def setup_credentials():
    """
    Download and create required credentials files.
    Return True if credentials were set up.
    Return False is credentials were already set up.
    :param force: boolean
    :return: boolean
    """

    # Test for DODS_FILE and only re-get credentials if it doesn't
    # exist AND `force` is True AND certificate is in-date.
    if cert_is_valid(CREDENTIALS_FILE_PATH):
        print('[INFO] Security credentials already set up.')
        return False

    # Get CEDA username and password from environment variables
    username = ''
    password = ''


    onlineca_client = OnlineCaClient()
    onlineca_client.ca_cert_dir = TRUSTROOTS_DIR

    # Set up trust roots
    trustroots = onlineca_client.get_trustroots(
        TRUSTROOTS_SERVICE,
        bootstrap=True,
        write_to_ca_cert_dir=True)

    # Write certificate credentials file
    key_pair, certs = onlineca_client.get_certificate(
        username,
        password,
        CERT_SERVICE,
        pem_out_filepath=CREDENTIALS_FILE_PATH)

    print('[INFO] Security credentials set up.')
    return True


def main(list_dates):
    """
    Main controller function.
    :param list_dates: list with all the dates required for the end-point
    :param nc_file_url: URL to a NetCDF4 opendap end-point.
    :param var_id: Variable ID [String]
    :return: None
    """

    try:
        setup_credentials()
    except KeyError:
        print("CEDA_USERNAME and CEDA_PASSWORD environment variables required")
        return
    
    # Download file to current working directory
    for fecha in list_dates:
        lst_day = calendar.monthrange(fecha.year, fecha.month)[1]

        url_p1 = 'https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/'
        url_p2 = 'rainfall_hadukgrid_uk_5km_day_'

        # Use f-strings to get padded date and month
        url = url_p1 + url_p2 + f"{fecha:%Y%m%d}" + '-' + f"{fecha:%Y%m}" + str(lst_day) + '.nc'
        print('Downloading: {}'.format(url))
            
        response = requests.get(url, cert=(CREDENTIALS_FILE_PATH), verify=False)
        filename = url.rsplit('/', 1)[-1]
        
        with open(filename, 'wb') as file_object:
            file_object.write(response.content)
            print('contents of URL written to: {} '.format(filename))
            print(sep)


if __name__ == '__main__':

    try:
        # Create dates list ready to pass in main function

        # Set loop to go through years - from 2000 to 2019
        dates_lst = []
        year = 2001

        # create date objects
        begin_year = datetime.date(year, 1, 1)
        end_year = datetime.date(2019, 12, 31)
        next_year = begin_year

        while next_year <= end_year:
            dates_lst.append(next_year)
            next_year = next_year +  relativedelta(months=+1)
        
        # Download the data
        main(dates_lst)
            
    except IndexError:
        print("Please provide a file URL as input")

print(sep)
print('All done!!. Check files')
# Out:
# [INFO] Security credentials already set up.
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20010101-20010131.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20010101-20010131.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20010201-20010228.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20010201-20010228.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20010301-20010331.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20010301-20010331.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20010401-20010430.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20010401-20010430.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20010501-20010531.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20010501-20010531.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20010601-20010630.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20010601-20010630.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20010701-20010731.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20010701-20010731.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20010801-20010831.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20010801-20010831.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20010901-20010930.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20010901-20010930.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20011001-20011031.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20011001-20011031.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20011101-20011130.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20011101-20011130.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20011201-20011231.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20011201-20011231.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20020101-20020131.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20020101-20020131.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20020201-20020228.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20020201-20020228.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20020301-20020331.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20020301-20020331.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20020401-20020430.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20020401-20020430.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20020501-20020531.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20020501-20020531.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20020601-20020630.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20020601-20020630.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20020701-20020731.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20020701-20020731.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20020801-20020831.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20020801-20020831.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20020901-20020930.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20020901-20020930.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20021001-20021031.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20021001-20021031.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20021101-20021130.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20021101-20021130.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20021201-20021231.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20021201-20021231.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20030101-20030131.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20030101-20030131.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20030201-20030228.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20030201-20030228.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20030301-20030331.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20030301-20030331.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20030401-20030430.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20030401-20030430.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20030501-20030531.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20030501-20030531.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20030601-20030630.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20030601-20030630.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20030701-20030731.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20030701-20030731.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20030801-20030831.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20030801-20030831.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20030901-20030930.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20030901-20030930.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20031001-20031031.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20031001-20031031.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20031101-20031130.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20031101-20031130.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20031201-20031231.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20031201-20031231.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20040101-20040131.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20040101-20040131.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20040201-20040229.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20040201-20040229.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20040301-20040331.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20040301-20040331.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20040401-20040430.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20040401-20040430.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20040501-20040531.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20040501-20040531.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20040601-20040630.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20040601-20040630.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20040701-20040731.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20040701-20040731.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20040801-20040831.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20040801-20040831.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20040901-20040930.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20040901-20040930.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20041001-20041031.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20041001-20041031.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20041101-20041130.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20041101-20041130.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20041201-20041231.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20041201-20041231.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20050101-20050131.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20050101-20050131.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20050201-20050228.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20050201-20050228.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20050301-20050331.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20050301-20050331.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20050401-20050430.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20050401-20050430.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20050501-20050531.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20050501-20050531.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20050601-20050630.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20050601-20050630.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20050701-20050731.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20050701-20050731.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20050801-20050831.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20050801-20050831.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20050901-20050930.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20050901-20050930.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20051001-20051031.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20051001-20051031.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20051101-20051130.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20051101-20051130.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20051201-20051231.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20051201-20051231.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20060101-20060131.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20060101-20060131.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20060201-20060228.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20060201-20060228.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20060301-20060331.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20060301-20060331.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20060401-20060430.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20060401-20060430.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20060501-20060531.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20060501-20060531.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20060601-20060630.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20060601-20060630.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20060701-20060731.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20060701-20060731.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20060801-20060831.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20060801-20060831.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20060901-20060930.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20060901-20060930.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20061001-20061031.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20061001-20061031.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20061101-20061130.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20061101-20061130.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20061201-20061231.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20061201-20061231.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20070101-20070131.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20070101-20070131.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20070201-20070228.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20070201-20070228.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20070301-20070331.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20070301-20070331.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20070401-20070430.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20070401-20070430.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20070501-20070531.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20070501-20070531.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20070601-20070630.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20070601-20070630.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20070701-20070731.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20070701-20070731.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20070801-20070831.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20070801-20070831.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20070901-20070930.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20070901-20070930.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20071001-20071031.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20071001-20071031.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20071101-20071130.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20071101-20071130.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20071201-20071231.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20071201-20071231.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20080101-20080131.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20080101-20080131.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20080201-20080229.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20080201-20080229.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20080301-20080331.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20080301-20080331.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20080401-20080430.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20080401-20080430.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20080501-20080531.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20080501-20080531.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20080601-20080630.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20080601-20080630.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20080701-20080731.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20080701-20080731.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20080801-20080831.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20080801-20080831.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20080901-20080930.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20080901-20080930.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20081001-20081031.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20081001-20081031.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20081101-20081130.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20081101-20081130.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20081201-20081231.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20081201-20081231.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20090101-20090131.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20090101-20090131.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20090201-20090228.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20090201-20090228.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20090301-20090331.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20090301-20090331.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20090401-20090430.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20090401-20090430.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20090501-20090531.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20090501-20090531.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20090601-20090630.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20090601-20090630.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20090701-20090731.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20090701-20090731.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20090801-20090831.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20090801-20090831.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20090901-20090930.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20090901-20090930.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20091001-20091031.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20091001-20091031.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20091101-20091130.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20091101-20091130.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20091201-20091231.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20091201-20091231.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20100101-20100131.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20100101-20100131.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20100201-20100228.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20100201-20100228.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20100301-20100331.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20100301-20100331.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20100401-20100430.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20100401-20100430.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20100501-20100531.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20100501-20100531.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20100601-20100630.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20100601-20100630.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20100701-20100731.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20100701-20100731.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20100801-20100831.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20100801-20100831.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20100901-20100930.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20100901-20100930.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20101001-20101031.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20101001-20101031.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20101101-20101130.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20101101-20101130.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20101201-20101231.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20101201-20101231.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20110101-20110131.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20110101-20110131.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20110201-20110228.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20110201-20110228.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20110301-20110331.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20110301-20110331.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20110401-20110430.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20110401-20110430.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20110501-20110531.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20110501-20110531.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20110601-20110630.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20110601-20110630.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20110701-20110731.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20110701-20110731.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20110801-20110831.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20110801-20110831.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20110901-20110930.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20110901-20110930.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20111001-20111031.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20111001-20111031.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20111101-20111130.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20111101-20111130.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20111201-20111231.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20111201-20111231.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20120101-20120131.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20120101-20120131.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20120201-20120229.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20120201-20120229.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20120301-20120331.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20120301-20120331.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20120401-20120430.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20120401-20120430.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20120501-20120531.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20120501-20120531.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20120601-20120630.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20120601-20120630.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20120701-20120731.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20120701-20120731.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20120801-20120831.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20120801-20120831.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20120901-20120930.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20120901-20120930.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20121001-20121031.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20121001-20121031.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20121101-20121130.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20121101-20121130.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20121201-20121231.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20121201-20121231.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20130101-20130131.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20130101-20130131.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20130201-20130228.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20130201-20130228.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20130301-20130331.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20130301-20130331.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20130401-20130430.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20130401-20130430.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20130501-20130531.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20130501-20130531.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20130601-20130630.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20130601-20130630.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20130701-20130731.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20130701-20130731.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20130801-20130831.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20130801-20130831.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20130901-20130930.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20130901-20130930.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20131001-20131031.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20131001-20131031.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20131101-20131130.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20131101-20131130.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20131201-20131231.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20131201-20131231.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20140101-20140131.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20140101-20140131.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20140201-20140228.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20140201-20140228.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20140301-20140331.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20140301-20140331.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20140401-20140430.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20140401-20140430.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20140501-20140531.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20140501-20140531.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20140601-20140630.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20140601-20140630.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20140701-20140731.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20140701-20140731.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20140801-20140831.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20140801-20140831.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20140901-20140930.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20140901-20140930.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20141001-20141031.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20141001-20141031.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20141101-20141130.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20141101-20141130.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20141201-20141231.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20141201-20141231.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20150101-20150131.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20150101-20150131.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20150201-20150228.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20150201-20150228.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20150301-20150331.nc
# ...
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20150701-20150731.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20150701-20150731.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20150801-20150831.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20150801-20150831.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20150901-20150930.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20150901-20150930.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20151001-20151031.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20151001-20151031.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20151101-20151130.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20151101-20151130.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20151201-20151231.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20151201-20151231.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20160101-20160131.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20160101-20160131.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20160201-20160229.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20160201-20160229.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20160301-20160331.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20160301-20160331.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20160401-20160430.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20160401-20160430.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20160501-20160531.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20160501-20160531.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20160601-20160630.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20160601-20160630.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20160701-20160731.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20160701-20160731.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20160801-20160831.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20160801-20160831.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20160901-20160930.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20160901-20160930.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20161001-20161031.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20161001-20161031.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20161101-20161130.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20161101-20161130.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20161201-20161231.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20161201-20161231.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20170101-20170131.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20170101-20170131.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20170201-20170228.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20170201-20170228.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20170301-20170331.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20170301-20170331.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20170401-20170430.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20170401-20170430.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20170501-20170531.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20170501-20170531.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20170601-20170630.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20170601-20170630.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20170701-20170731.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20170701-20170731.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20170801-20170831.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20170801-20170831.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20170901-20170930.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20170901-20170930.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20171001-20171031.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20171001-20171031.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20171101-20171130.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20171101-20171130.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20171201-20171231.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20171201-20171231.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20180101-20180131.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20180101-20180131.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20180201-20180228.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20180201-20180228.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20180301-20180331.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20180301-20180331.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20180401-20180430.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20180401-20180430.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20180501-20180531.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20180501-20180531.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20180601-20180630.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20180601-20180630.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20180701-20180731.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20180701-20180731.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20180801-20180831.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20180801-20180831.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20180901-20180930.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20180901-20180930.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20181001-20181031.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20181001-20181031.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20181101-20181130.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20181101-20181130.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20181201-20181231.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20181201-20181231.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20190101-20190131.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20190101-20190131.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20190201-20190228.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20190201-20190228.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20190301-20190331.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20190301-20190331.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20190401-20190430.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20190401-20190430.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20190501-20190531.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20190501-20190531.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20190601-20190630.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20190601-20190630.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20190701-20190731.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20190701-20190731.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20190801-20190831.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20190801-20190831.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20190901-20190930.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20190901-20190930.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20191001-20191031.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20191001-20191031.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20191101-20191130.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20191101-20191130.nc
# ------------
# ------------
# Downloading: https://dap.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.2.1/5km/rainfall/day/v20200731/rainfall_hadukgrid_uk_5km_day_20191201-20191231.nc
# contents of URL written to: rainfall_hadukgrid_uk_5km_day_20191201-20191231.nc
# ------------
# ------------
# ------------
# ------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_15995/2519820506.py in <module>
#     180
#     181 print(sep)
# --> 182 print('All done!!. Check files in: {}'.format(fld_out))
#
# NameError: name 'fld_out' is not defined
# Error in atexit._run_exitfuncs:
# Traceback (most recent call last):
#   File "/home/lfpv/.local/lib/python3.8/site-packages/IPython/core/history.py", line 780, in writeout_cache
#     self._writeout_input_cache(conn)
#   File "/home/lfpv/.local/lib/python3.8/site-packages/IPython/core/history.py", line 763, in _writeout_input_cache
#     conn.execute("INSERT INTO history VALUES (?, ?, ?, ?)",
# sqlite3.DatabaseError: database disk image is malformed
