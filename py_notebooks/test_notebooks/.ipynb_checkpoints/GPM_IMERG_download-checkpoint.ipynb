# %% [markdown]
# # Donwloading GPM-IMERG Data

# %%
"""==============================================================================

 Title          :GPM_IMERG_download.ipynb
 Description    :Download GPM IMERG data from Nasa server
 Author         :LF Velasquez - MA
 Date           :May 20 2021
 Version        :1.0
 Usage          :GPM_IMERG_download.ipynb
 Notes          : 
                - The user must have a earthdata account
                - This code is based on the code developed by Peter Smith, last modified by Srikanth Davu
                  https://wiki.earthdata.nasa.gov/display/EL/How+To+Access+Data+With+Python
 python version :3.8.5

=============================================================================="""
# Out:
# '==============================================================================\n\n Title          :GPM_IMERG_download.ipynb\n Description    :Download GPM IMERG data from Nasa server\n Author         :LF Velasquez - MA\n Date           :May 20 2021\n Version        :1.0\n Usage          :GPM_IMERG_download.ipynb\n Notes          : \n                - The user must have a earthdata account\n                - This code is based on the code developed by Peter Smith, last modified by Srikanth Davu\n                  https://wiki.earthdata.nasa.gov/display/EL/How+To+Access+Data+With+Python\n python version :3.8.5\n\n=============================================================================='

# %% [markdown]
# **Importing Modules**

# %%
from http.cookiejar import CookieJar
from urllib.parse import urlencode
from pathlib import Path
import urllib.request as urllib2
import requests
import datetime
import xarray as xr
import pydap

# %% [markdown]
# **Adding data directory**

# %%
# FILEPATH = Path('/mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk/') # path for Earthdata data
# FILEPATH = Path('/mnt/d/MRes_dataset/search_data/gear_ceh_uk/') # path for CEH data store data
FILEPATH = Path('/mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/') # path for CEH data store data


# uncomment below to check if it is the right path
# !ls {FILEPATH}

# %% [markdown]
# **Functions**

# %%
def data_download(data_url, file_2save):
    result = requests.get(data_url)
    try:
        result.raise_for_status()
        f = open(file_2save,'wb')
        f.write(result.content)
        f.close()
        print('contents of URL written to: {} '.format(file_2save))
    except:
        print('requests.get() returned an error code: {}'.format(str(result.status_code)))

# %% [markdown]
# **Set Earthdata information**

# %%
# Credential

# Earth data
username = "GeoFelpave"
password = "G4htaQv444"

# # CEH data store
# username = "l.f.patino-velasquez2@newcastle.ac.uk"
# password = "zU8Y5fF9IlUq"

# Create password manager for 401 response
password_manager = urllib2.HTTPPasswordMgrWithDefaultRealm()
password_manager.add_password(None, "https://urs.earthdata.nasa.gov", username, password) #Earthdata url
# password_manager.add_password(None, "https://catalogue.ceh.ac.uk", username, password) #CEH data store url

# Create cookie jar to store cookies. This will avoid having to authenticate user everytime data is requested
cookie_jar = CookieJar()

# Install handlers
opener = urllib2.build_opener(
    urllib2.HTTPBasicAuthHandler(password_manager),
    #urllib2.HTTPHandler(debuglevel=1),    # Uncomment these two lines to see
    #urllib2.HTTPSHandler(debuglevel=1),   # details of the requests/responses
    urllib2.HTTPCookieProcessor(cookie_jar))
urllib2.install_opener(opener)

# %% [markdown]
# # Working with Earthdata data
# **Create list with dates**

# %%
# Create dates list ready to pass in URL

# Set loop to go through years - from 2000 to 2019
dates_lst = []
year = 2001

# create date objects
begin_year = datetime.date(year, 1, 1)
end_year = datetime.date(2001, 12, 31)
# end_year = datetime.date(2019, 12, 31)
one_day = datetime.timedelta(days=1)

next_day = begin_year
for day in range(0, 366):  # includes potential leap year
    while next_day <= end_year:
        if next_day > datetime.date(2000, 5, 31): # gpm imerg data only start in 2000/06
            dates_lst.append(next_day)
        # increment date object by one day
        next_day += one_day

# %% [markdown]
# **Working with the date list to request the data**

# %%
# set list for url that can be reached
for date in dates_lst:
    url_p1 = 'https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06
S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20010502-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/05/3B-DAY.MS.MRG.3IMERG.20010503-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20010503-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/05/3B-DAY.MS.MRG.3IMERG.20010504-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20010504-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/05/3B-DAY.MS.MRG.3IMERG.20010505-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20010505-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/05/3B-DAY.MS.MRG.3IMERG.20010506-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20010506-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/05/3B-DAY.MS.MRG.3IMERG.20010507-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20010507-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/05/3B-DAY.MS.MRG.3IMERG.20010508-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20010508-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/05/3B-DAY.MS.MRG.3IMERG.20010509-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20010509-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/05/3B-DAY.MS.MRG.3IMERG.20010510-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20010510-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/05/3B-DAY.MS.MRG.3IMERG.20010511-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20010511-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/05/3B-DAY.MS.MRG.3IMERG.20010512-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20010512-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/05/3B-DAY.MS.MRG.3IMERG.20010513-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20010513-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/05/3B-DAY.MS.MRG.3IMERG.20010514-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20010514-S000000-E235959.V06.nc4.nc4
# ...
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/11/3B-DAY.MS.MRG.3IMERG.20011118-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011118-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/11/3B-DAY.MS.MRG.3IMERG.20011119-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011119-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/11/3B-DAY.MS.MRG.3IMERG.20011120-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011120-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/11/3B-DAY.MS.MRG.3IMERG.20011121-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011121-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/11/3B-DAY.MS.MRG.3IMERG.20011122-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011122-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/11/3B-DAY.MS.MRG.3IMERG.20011123-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011123-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/11/3B-DAY.MS.MRG.3IMERG.20011124-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011124-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/11/3B-DAY.MS.MRG.3IMERG.20011125-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011125-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/11/3B-DAY.MS.MRG.3IMERG.20011126-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011126-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/11/3B-DAY.MS.MRG.3IMERG.20011127-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011127-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/11/3B-DAY.MS.MRG.3IMERG.20011128-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011128-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/11/3B-DAY.MS.MRG.3IMERG.20011129-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011129-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/11/3B-DAY.MS.MRG.3IMERG.20011130-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011130-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/12/3B-DAY.MS.MRG.3IMERG.20011201-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011201-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/12/3B-DAY.MS.MRG.3IMERG.20011202-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011202-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/12/3B-DAY.MS.MRG.3IMERG.20011203-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011203-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/12/3B-DAY.MS.MRG.3IMERG.20011204-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011204-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/12/3B-DAY.MS.MRG.3IMERG.20011205-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011205-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/12/3B-DAY.MS.MRG.3IMERG.20011206-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011206-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/12/3B-DAY.MS.MRG.3IMERG.20011207-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011207-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/12/3B-DAY.MS.MRG.3IMERG.20011208-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011208-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/12/3B-DAY.MS.MRG.3IMERG.20011209-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011209-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/12/3B-DAY.MS.MRG.3IMERG.20011210-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011210-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/12/3B-DAY.MS.MRG.3IMERG.20011211-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011211-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/12/3B-DAY.MS.MRG.3IMERG.20011212-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011212-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/12/3B-DAY.MS.MRG.3IMERG.20011213-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011213-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/12/3B-DAY.MS.MRG.3IMERG.20011214-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011214-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/12/3B-DAY.MS.MRG.3IMERG.20011215-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011215-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/12/3B-DAY.MS.MRG.3IMERG.20011216-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011216-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/12/3B-DAY.MS.MRG.3IMERG.20011217-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011217-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/12/3B-DAY.MS.MRG.3IMERG.20011218-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011218-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/12/3B-DAY.MS.MRG.3IMERG.20011219-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011219-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/12/3B-DAY.MS.MRG.3IMERG.20011220-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011220-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/12/3B-DAY.MS.MRG.3IMERG.20011221-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011221-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/12/3B-DAY.MS.MRG.3IMERG.20011222-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011222-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/12/3B-DAY.MS.MRG.3IMERG.20011223-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011223-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/12/3B-DAY.MS.MRG.3IMERG.20011224-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011224-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/12/3B-DAY.MS.MRG.3IMERG.20011225-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011225-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/12/3B-DAY.MS.MRG.3IMERG.20011226-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011226-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/12/3B-DAY.MS.MRG.3IMERG.20011227-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011227-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/12/3B-DAY.MS.MRG.3IMERG.20011228-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011228-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/12/3B-DAY.MS.MRG.3IMERG.20011229-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011229-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/12/3B-DAY.MS.MRG.3IMERG.20011230-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011230-S000000-E235959.V06.nc4.nc4
# https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2001/12/3B-DAY.MS.MRG.3IMERG.20011231-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1709:1819][1389:1509],time,lon[1709:1819],lat[1389:1509]
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2/3B-DAY.MS.MRG.3IMERG.20011231-S000000-E235959.V06.nc4.nc4
# --------------
# --------------
# Check files here: /mnt/d/MRes_dataset/search_data/gpm_imerg_nasa_uk_test_v2
# --------------
# --------------
# This is the URL to check

# %% [markdown]
# # Working with CEH datastore
# **Create list of years** (*The daily data is stored by year*)

# %%
# Create dates list ready to pass in URL
# add relativedata module
from dateutil.relativedelta import relativedelta

# Set loop to go through years - from 2000 to 2019
year_lst = []
year = 2000

# Create date objects
begin_year = datetime.date(2000,1,1)
end_year = datetime.date(2017, 12, 31)
one_year = relativedelta(years=1)

# Append year as a string to the year list
next_year = begin_year
while next_year <= end_year:
    year_lst.append(f"{next_year:%Y}")
    next_year += one_year
print(year_lst)
# Out:
# ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017']

# %% [markdown]
# **Working with the date list to request the data**

# %%
# set list for url that can be reached
for year in year_lst:
    url_p1 = 'https://catalogue.ceh.ac.uk/datastore/eidchub/ee9ab43d-a4fe-4e73-afd5-cd4fc4c82556/GB/daily/CEH_GEAR_daily_GB_'

    # Use f-strings to get padded date and month
    url = url_p1 + year + '.nc'
    print(url)
    
    # Create file to save data in local drive
    FILENAME = 'CEH_GEAR_daily_GB_' + year + '.nc'
    SAVEFILE = Path(FILEPATH / FILENAME)
    
    # Run request using function
    data_download(url, SAVEFILE)
    break
    
print ('--------------')
print ('--------------')
print ('Check files here: {}'.format(FILEPATH ))
print ('--------------')
print ('--------------')
print ('This is the URL to check')
# Out:
# https://catalogue.ceh.ac.uk/datastore/eidchub/ee9ab43d-a4fe-4e73-afd5-cd4fc4c82556/GB/daily/CEH_GEAR_daily_GB_2000.nc
# contents of URL written to: /mnt/d/MRes_dataset/search_data/gear_ceh_uk/CEH_GEAR_daily_GB_2000.nc
# --------------
# --------------
# Check files here: /mnt/d/MRes_dataset/search_data/gear_ceh_uk
# --------------
# --------------
# This is the URL to check

# %% [markdown]
# ## Data download check
#
# - The code below will only need to be run after doing the download of the data
# - The code checks the files downloaded against the files that are expected based on the years
# - If the file has not been downloaded, the code will try to download the code again

# %%
# Create list of file names
name_lst = []
for date in dates_lst:
    part1 = '3B-DAY.MS.MRG.3IMERG.'
    part2 = '-S000000-E235959.V06.nc4.nc4'
    file_name = part1 + f"{date:%Y%m%d}" + part2
    name_lst.append(file_name)

# Create list of file names in folder
file_lst = []
python_files = FILEPATH.glob('**/*.nc4') 
for pf in python_files:
    file_lst.append(pf.parts[6])
    
# Compare the two list and get missing values
# the main list is name_lst as it contains names of expected files
missing = list(sorted(set(name_lst) - set(file_lst)))
print ('There are {} missing files in the folder \n'.format(len(missing)))

# print ('--------------')
# print ('--------------')
print ('Trying to download the files again')
# print ('--------------')
# print ('--------------')

# set list for url that can be reached
'3B-DAY.MS.MRG.3IMERG.20000604-S000000-E235959.V06.nc4.nc4'

if len(missing) > 0:
    fd
    url_toCheck = []
    for file_name in missing:
        url_p1 = 'https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/'
        url_p2 = file_name
        url_p3 = '?precipitationCal[0:0][1709:1819][1389:1509],time_bnds[0:0][0:1],time,lon[1709:1819],lat[1389:1509]'

        # Get year and month from the file name
        year = file_name.split('.')[4][:4]
        month = file_name.split('.')[4][:6][-2:]

    #     build URL
        url = url_p1 + year + '/' + month + '/' + file_name + url_p3
        print(url)

        # Create file to save data in local drive
        FILENAME = file_name
        SAVEFILE = Path(FILEPATH / FILENAME)

        # Run request using function
        data_nasa(url, SAVEFILE)

    print ('--------------')
    print ('--------------')
    print ('Check files here: {}'.format(FILEPATH ))
    print ('--------------')
    print ('--------------')
else:
    print ('--------------')
    print ('--------------')
    print ('All the files have been downloaded!')
    print ('--------------')
    print ('--------------')
# Out:
# There are 0 missing files in the folder
#
# Trying to download the files again
# --------------
# --------------
# All the files have been downloaded!
# --------------
# --------------
